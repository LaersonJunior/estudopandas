# %%
import pandas as pd

# Carregando o dataset corretamente que utiliza o separador ";"
data = pd.read_csv('D:\GitHub\EstudoPandas\.venv\dataset\GasPricesinBrazil_2004-2019.csv', sep=';')

# # Verificar tipo, colunas e se obtem valor Null
# print(data.dtypes,
#       data.head(),
#       data.isnull().sum())

# # Corrigido para acessar corretamente as dimensões
# print(f'O Dataframe possui {data.shape[0]} linhas/observações/registros e {data.shape[1]} colunas/variáveis/atributos')


personagens_df = pd.DataFrame({
    'nome':['Luke SkyWalker','Yoda','Palpatine'],
    'idade':['16','1000','70'],
    'peso':['70','15','60'],
    'eh jedi':[True,True,False] #O nome da coluna pode ter espaço
})

# print(personagens_df.info())

# Renoemando as colunas
presonagens_df_renomeado = personagens_df.rename(columns={'nome':'Nome Completo','idade':'Idade'})

# Renomear direto no dataframe
personagens_df.rename(columns={
    'nome':'Nome Completo',
    'idade':'Idade'},inplace=True)



personagens_df.columns = ['NOME','IDADE','PESO','EH_JEDI']

# SERIES
# selecioando uma coluna inteira

# print(data.ESTADO) # Não é recomendado


# print(data['ESTADO'])

# print(type(data['ESTADO']))

# print(data.iloc[1]) # Acessando a segunda linha


# print(pd.Series([5.5,6.0,9.5],index=['Prova1','Prova2','Projeto'],name='Notas'))

# Quanto utiliza a cosntante, somente é um view do dataframe.
produto_view = (data['PRODUTO']) 

# # Cópia do dataframe
# produto_copy_bkp=data['PRODUTO'].copy()

# Atribuindo o valor constante 'Combustivel' a todos os registros da coluna 'PRODUTO'
# data['PRODUTO'] = 'Combustivel'

nrows, ncols = data.shape


# novos_produtos = [ f'Produto {i}' for i in range(nrows)]

# # A Quantidade de elementos da lista deve ser igual ao número de linhas do dataframe
# data['PRODUTO'] = novos_produtos

# data['PRODUTO']= produto_copy_bkp

# Criando uma coluna a partir de um valor constante/default
data['Coluna sem Nocao'] = 'DEFAULT'

# Criando uma coluina a partir de uma lista
data['Coluna a Partir de Lista'] =  range(data.shape[0])

# # Não funciona, devido a quantidade linhas do dataframe
# data['Não Funcionana'] = [1,2,3]

data['PREÇO MÉDIO REVENDA (dólares)'] = data['PREÇO MÉDIO REVENDA'] * 6.0

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
pesquisa_de_satisfacao=pd.DataFrame({
    'Bom':[50,21,100],
    'Ruim':[21,2,20],
    'Pessimo':[100,30,1]
},index=['XboxOne','Playstation 4','Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#                Bom  Ruim  Pessimo
# XboxOne         50    21      100
# Playstation 4   21     2       30
# Switch         100    20        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation 4', 'Switch'], dtype='object')

# %%
# seleciona a linha 1
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %%
data.iloc[1,3]
# Out:
# 'CENTRO OESTE'

# %%
pesquisa_de_satisfacao
# Out:
#                Bom  Ruim  Pessimo
# XboxOne         50    21      100
# Playstation 4   21     2       30
# Switch         100    20        1

# %%
# Retorna a linha de Indice 0 Implcito   
pesquisa_de_satisfacao.iloc[0]
# Out:
# Bom         50
# Ruim        21
# Pessimo    100
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao.iloc[0,1]
# Out:
# np.int64(21)

# %%
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# Bom         50
# Ruim        21
# Pessimo    100
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao
# Out:
#                Bom  Ruim  Pessimo
# XboxOne         50    21      100
# Playstation 4   21     2       30
# Switch         100    20        1

# %%
# Retornar Valor da LInhaa 'Playstation 4' e Coluna 'Ruim'
pesquisa_de_satisfacao.loc['Playstation 4','Ruim']
# Out:
# np.int64(2)

# %%
# Retornar valor das linhas de indices rotulados 'XboxOne' e 'Switch'
pesquisa_de_satisfacao.loc[['XboxOne','Switch']]
# Out:
#          Bom  Ruim  Pessimo
# XboxOne   50    21      100
# Switch   100    20        1

# %%
# Retornar todas as linhas e apenas as colunas com rotulos 'Bom' e 'Ruim'
pesquisa_de_satisfacao[['Bom','Pessimo']]
# Out:
#                Bom  Pessimo
# XboxOne         50      100
# Playstation 4   21       30
# Switch         100        1

# %%
# Retornar todas as linhas e apenas as colunas com rotulos 'Bom' e 'Ruim'
pesquisa_de_satisfacao.loc[:,['Bom','Pessimo']]
# Out:
#                Bom  Pessimo
# XboxOne         50      100
# Playstation 4   21       30
# Switch         100        1

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# A FORMA DE ACESSO DE COLUNAS POR .NOME_DA_COLUNA SO FUNCIONA SE 
# NOME_DA_COLUNA NÃO POSSURI CARACTERES INVALIDOS (ESPEAÇOS, ACESNTOS, ETC)
# data.DATA INICIAL

# %%
data['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 106818    2019-06-23
# 106819    2019-06-23
# 106820    2019-06-23
# 106821    2019-06-23
# 106822    2019-06-23
# Name: DATA INICIAL, Length: 106823, dtype: object

# %%
data[['PRODUTO','ESTADO','REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
# Deleta/Remove in-place no proprio dataframe
del data['Unnamed: 0']

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
del data['Coluna sem Nocao']
del data['Coluna a Partir de Lista']
del data['PREÇO MÉDIO REVENDA (dólares)']

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data.to_csv('./dataset/GasPricesinBrazil_2004-2019_Preparado.csv',sep=',',index=False)

# %% [markdown]
#  - Seleção Condicional

# %%
data = pd.read_csv('./dataset/GasPricesinBrazil_2004-2019_Preparado.csv')

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# MOSTRA TODOS OS ESTADOS CUJA OS PREÇOS DOS COMBUSTIVEIS FORAM AFERIDOS
# MAS TECNICAMENTE, MOSTRA OS VALORES UNICOS PRESENTES PARA O ATRIBUTO 'ESTADO'

data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
# faz uma comparação elemento a elemento e retorna um array de booleanos
data['ESTADO']== 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
# salvar a seleção em uma variável
selecao  = data['ESTADO']== 'SAO PAULO'

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
selecao.shape
# Out:
# (106823,)

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
df1 = data[selecao]

# %%
df1
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
df1.to_excel('./dataset/SaoPaulo.xlsx', index=False, engine='openpyxl')

# %%
data.loc[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# ASPAS DUPLAS PARA INFORMAR O NOME DO VALOR A SER SELECIONADO
data.query('ESTADO=="SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
postos_sp = data.query('ESTADO=="SAO PAULO"')

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
type(postos_sp)
# Out:
# pandas.core.frame.DataFrame

# %%
postos_sp.shape
# Out:
# (4263, 20)

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
# Se não incluir inplace sera uma copia e não ateualizara o dataframe original
postos_sp.reset_index(drop=True,inplace=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
# alteranativa comum
postos_sp = data.query('ESTADO=="SAO PAULO"').reset_index(drop=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data['ESTADO']=='RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA']>2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
selecao_RJ= (data['ESTADO']=='RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA']>2.0)

# %%
selecao_RJ
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %%
data[selecao_RJ]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %%
# não funciona devido a caracter especial e/ou espaços
# data.query('ESTADO=="RIO DE JANEIRO" AND PREÇO MÉDIO REVERENDA>2.0')

# %%
data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
selecao_1 = data['ESTADO']=='RIO DE JANEIRO'
postos_rj=data[selecao_1]
postos_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 103      2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 130      2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %%
selecao_2 = postos_rj['PREÇO MÉDIO REVENDA']>2.0
selecao_2
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 106718     True
# 106745     True
# 106772     True
# 106799     True
# 106817     True
# Name: PREÇO MÉDIO REVENDA, Length: 4263, dtype: bool

# %%
postos_rj_precos_maior_que_2 = postos_rj[selecao_2]

# %%
postos_rj_precos_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %%
(data['ESTADO']=='SAO PAULO') | (data['ESTADO']=='RIO DE JANEIRO')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
sp_rj = (data['ESTADO']=='SAO PAULO') | (data['ESTADO']=='RIO DE JANEIRO')

# %%
sp_rj
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# Verificando se as colunas existem antes de deletá-las
columns_to_delete = ['Unnamed: 0', 'Coluna sem Nocao', 'Coluna a Partir de Lista', 'PREÇO MÉDIO REVENDA (dólares)']
for col in columns_to_delete:
    if col in data.columns:
        del data[col]

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data.to_csv('./dataset/GasPricesinBrazil_2004-2019_Tratado.csv',sep=',',index=False)

# %%
data_df = pd.read_csv('./dataset/GasPricesinBrazil_2004-2019_Tratado.csv')

# %%
data_df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
filtro1 =(data_df['ESTADO']=='SAO PAULO') | (data['ESTADO']=='RIO DE JANEIRO')

filtro2 = (data_df['PRODUTO']=='GASOLINA COMUM')

filtro3 = (data_df['PREÇO MÉDIO REVENDA']>2.0)

filtro_final = filtro1 & filtro2 & filtro3

# %% [markdown]
# 1 - Valores referente estados de  São Paulo ou Rio de Janeiro com valores **Preço Médio de Revenda** maiores que **2**.</br>

# %%
data[filtro_final]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
filtro_final_real= data[filtro_final]

# %%
filtro_final_real
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
print(filtro_final_real['ESTADO'].unique())
print(filtro_final_real['PRODUTO'].unique())
# Out:
# ['RIO DE JANEIRO' 'SAO PAULO']
# ['GASOLINA COMUM']

# %%
filtro1 =(data_df['ESTADO']=='SAO PAULO') | (data['ESTADO']=='RIO DE JANEIRO')

postos_sp_rj = data_df[filtro1]

postos_sp_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
# ...

# %%
filtro2_1 = postos_sp_rj['PRODUTO']== 'GASOLINA COMUM'
filtro2_1
# Out:
# 22        False
# 23        False
# 49        False
# 50        False
# 76        False
#           ...
# 106778     True
# 106799    False
# 106805    False
# 106817    False
# 106821    False
# Name: PRODUTO, Length: 8526, dtype: bool

# %%
postos_sp_rj_gasolina = postos_sp_rj[filtro2_1]
postos_sp_rj_gasolina
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12087    2004-05-09  2004-05-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12114    2004-05-16  2004-05-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
filtro3_1 = (postos_sp_rj_gasolina['PREÇO MÉDIO REVENDA']>2.0)
filtro3_1
# Out:
# 12086      True
# 12087     False
# 12113      True
# 12114     False
# 12140      True
#           ...
# 106479     True
# 106623     True
# 106629     True
# 106772     True
# 106778     True
# Name: PREÇO MÉDIO REVENDA, Length: 1570, dtype: bool

# %%
postos_sp_rj_gasolina_preco_maior_que_2 = postos_sp_rj_gasolina[filtro3_1]

# %%
postos_sp_rj_gasolina_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
postos_sp_rj_gasolina_preco_maior_que_2.to_csv('./dataset/Postos_SP_RJ_Gasolina_Preco_Maior_Que_2.csv',sep=',',index=False)

# %%
data_df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# ALTERANATIVA DE **FILTRAGEM DINAMICA 1** </br>

# %%
filtro_ano = (data['ANO']==2008) | (data['ANO']==2010) | (data['ANO']==2012)
filtro_ano
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ANO, Length: 106823, dtype: bool

# %%
Ano_filtrados = data_df[filtro_ano]
Ano_filtrados
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# ALTERANATIVA DE **FILTRAGEM DINAMICA 2** </br>

# %%
lista_de_anos = [2008,2010,2012]

# %%
filtro_lista = data_df['ANO'].isin(lista_de_anos)
filtro_lista
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ANO, Length: 106823, dtype: bool

# %%
data_df[filtro_lista]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# ALTERANATIVA DE **FILTRAGEM DINAMICA 3** </br>

# %%
data_df.query('ANO in [2008,2010,2012]')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# ALTERANATIVA DE **FILTRAGEM DINAMICA 4** </br>

# %%
lista_de_anos2 = [2008,2010,2012]

# %%
data_df.query('ANO in @lista_de_anos2')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# **TOP 10** </br>

# %%
for index, row in data_df.head(10).iterrows():
    print(f'index: {index}, Estado: {row["ESTADO"]}, Preço Médio Revenda: {row["PREÇO MÉDIO REVENDA"]}')
# Out:
# index: 0, Estado: DISTRITO FEDERAL, Preço Médio Revenda: 1.288
# index: 1, Estado: GOIAS, Preço Médio Revenda: 1.162
# index: 2, Estado: MATO GROSSO, Preço Médio Revenda: 1.389
# index: 3, Estado: MATO GROSSO DO SUL, Preço Médio Revenda: 1.262
# index: 4, Estado: ALAGOAS, Preço Médio Revenda: 1.181
# index: 5, Estado: BAHIA, Preço Médio Revenda: 1.383
# index: 6, Estado: CEARA, Preço Médio Revenda: 1.453
# index: 7, Estado: MARANHAO, Preço Médio Revenda: 1.631
# index: 8, Estado: PARAIBA, Preço Médio Revenda: 1.284
# index: 9, Estado: PERNAMBUCO, Preço Médio Revenda: 1.224

# %%
data_df.head(5)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
# ...

# %%
data_pre = data_df.copy()

# %%
data_pre['DATA INICIAL']= pd.to_datetime(data_pre['DATA INICIAL'])

# %%
data_pre['DATA FINAL']= pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
for atributo in ['PREÇO MÉDIO REVENDA',
   'DESVIO PADRÃO REVENDA',
   'PREÇO MÍNIMO REVENDA',
   'PREÇO MÁXIMO REVENDA',
   'MARGEM MÉDIA REVENDA',
   'COEF DE VARIAÇÃO DISTRIBUIÇÃO',
   'PREÇO MÉDIO DISTRIBUIÇÃO',
   'DESVIO PADRÃO DISTRIBUIÇÃO',
   'PREÇO MÍNIMO DISTRIBUIÇÃO',
   'PREÇO MÁXIMO DISTRIBUIÇÃO',
   'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
    # Converte de String para nUmerico / Caso ocorra erro, atribui NaN
    data_pre[atributo] = pd.to_numeric(data_pre[atributo],errors='coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
data_pre
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
mask=data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
data_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data_df[mask]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25  2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09  2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23  2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26  2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27  2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106664   2019-06-16  2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16  2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23  2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23  2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23  2019-06-29      SUL          PARANA               GNV
#
# ...

# %%
data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data_pre_fill = data_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO':10,
    'DESVIO PADRÃO DISTRIBUIÇÃO':20,
    'PREÇO MÍNIMO DISTRIBUIÇÃO':30,
    'PREÇO MÁXIMO DISTRIBUIÇÃO':'vazio'
})

data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data_pre.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 data_pre.dropna(inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
data_pre[mask]
# Out:
# C:\Users\Laerson Junior\AppData\Local\Temp\ipykernel_12848\2742747452.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_pre[mask]
# Empty DataFrame
# Columns: [DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []

# %% [markdown]
# ***Análise Descritiva***

# %%
df=pd.read_csv('./dataset/GasPricesinBrazil_2004-2019_Preparado.csv')

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
df.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# ...

# %%
df['PREÇO MÁXIMO REVENDA'].describe()
# Out:
# count    103392.000000
# mean         12.458686
# std          20.801190
# min           0.999000
# 25%           2.330000
# 50%           3.000000
# 75%           4.150000
# max         120.000000
# Name: PREÇO MÁXIMO REVENDA, dtype: float64

# %%
df.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats=df.describe()
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# ...

# %%
stats.loc[['mean','max','min']]
# Out:
#       NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# mean                    240.511935            10.784472
# max                    4167.000000            99.357000
# min                       1.000000             0.766000
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# mean               0.652589              9.334931             12.458686
# max               10.748000             90.000000            120.000000
# min                0.000000              0.590000              0.999000
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# mean              2.225151                  0.045749
# max              36.847000                  0.262000
# min               0.001000                  0.000000
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# mean                  8.559322                    0.559441
# max                  83.137000                   18.385000
# ...

# %%
stats.loc[['min','max','mean'],['PREÇO MÉDIO REVENDA','PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#       PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# min              0.766000                  0.506000
# max             99.357000                 83.137000
# mean            10.784472                  8.559322

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
df['PREÇO MÍNIMO REVENDA'].min()
# Out:
# np.float64(0.59)

# %%
mean = df['PREÇO MÍNIMO REVENDA'].mean()
std = df['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços minimos de revenda é {mean:.2f} e o desvio padrão é {std:.2f}')
# Out:
# A média dos preços minimos de revenda é 9.33 e o desvio padrão é 15.02

# %%
df['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
sorted(df['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %%
df['ESTADO'].value_counts()
# Out:
# ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: count, dtype: int64

# %%
df_1 = df['ESTADO'].value_counts()

# %%
df_a = pd.DataFrame({'A':[1,2,3,4],
                     'B':[10,20,30,40],
                     'C':[100,200,300,400]},
                    index=['Linha 1','Linha 2','Linha 3','Linha 4'])

# %%
df_a
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
def nossa_soma (series):
    return series.sum()

# %%
df_a
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
df_a['SOMA(A,B,C)'] = df_a.apply(nossa_soma,axis=1)

# %%
df_a
# Out:
#          A   B    C  SOMA(A,B,C)
# Linha 1  1  10  100        111.0
# Linha 2  2  20  200        222.0
# Linha 3  3  30  300        333.0
# Linha 4  4  40  400        444.0

# %%
df_a.loc['Linha5']= df_a.apply(nossa_soma,axis=0)

# %%
df_a
# Out:
#             A      B       C  SOMA(A,B,C)
# Linha 1   1.0   10.0   100.0        111.0
# Linha 2   2.0   20.0   200.0        222.0
# Linha 3   3.0   30.0   300.0        333.0
# Linha 4   4.0   40.0   400.0        444.0
# Linha5   10.0  100.0  1000.0       1110.0

# %%
df_a['MEAN(A,B,C)'] = df_a[['A','B','C']].apply(lambda series: series.mean(), axis=1)

# %%
df_a
# Out:
#             A      B       C  SOMA(A,B,C)  MEAN(A,B,C)
# Linha 1   1.0   10.0   100.0        111.0         37.0
# Linha 2   2.0   20.0   200.0        222.0         74.0
# Linha 3   3.0   30.0   300.0        333.0        111.0
# Linha 4   4.0   40.0   400.0        444.0        148.0
# Linha5   10.0  100.0  1000.0       1110.0        370.0

# %%
df_a['Cx2']=df_a['C'].apply(lambda x: x*2)

# %%
df_a
# Out:
#             A      B       C  SOMA(A,B,C)  MEAN(A,B,C)     Cx2
# Linha 1   1.0   10.0   100.0        111.0         37.0   200.0
# Linha 2   2.0   20.0   200.0        222.0         74.0   400.0
# Linha 3   3.0   30.0   300.0        333.0        111.0   600.0
# Linha 4   4.0   40.0   400.0        444.0        148.0   800.0
# Linha5   10.0  100.0  1000.0       1110.0        370.0  2000.0
