# %%
import pandas as pd

# Carregando o dataset corretamente que utiliza o separador ";"
data = pd.read_csv('D:\GitHub\EstudoPandas\.venv\dataset\GasPricesinBrazil_2004-2019.csv', sep=';')

# # Verificar tipo, colunas e se obtem valor Null
# print(data.dtypes,
#       data.head(),
#       data.isnull().sum())

# # Corrigido para acessar corretamente as dimensões
# print(f'O Dataframe possui {data.shape[0]} linhas/observações/registros e {data.shape[1]} colunas/variáveis/atributos')


personagens_df = pd.DataFrame({
    'nome':['Luke SkyWalker','Yoda','Palpatine'],
    'idade':['16','1000','70'],
    'peso':['70','15','60'],
    'eh jedi':[True,True,False] #O nome da coluna pode ter espaço
})

# print(personagens_df.info())

# Renoemando as colunas
presonagens_df_renomeado = personagens_df.rename(columns={'nome':'Nome Completo','idade':'Idade'})

# Renomear direto no dataframe
personagens_df.rename(columns={
    'nome':'Nome Completo',
    'idade':'Idade'},inplace=True)



personagens_df.columns = ['NOME','IDADE','PESO','EH_JEDI']

# SERIES
# selecioando uma coluna inteira

# print(data.ESTADO) # Não é recomendado


# print(data['ESTADO'])

# print(type(data['ESTADO']))

# print(data.iloc[1]) # Acessando a segunda linha


# print(pd.Series([5.5,6.0,9.5],index=['Prova1','Prova2','Projeto'],name='Notas'))

# Quanto utiliza a cosntante, somente é um view do dataframe.
produto_view = (data['PRODUTO']) 

# Cópia do dataframe
produto_copy_bkp=data['PRODUTO'].copy()

# Atribuindo o valor constante 'Combustivel' a todos os registros da coluna 'PRODUTO'
# data['PRODUTO'] = 'Combustivel'

nrows, ncols = data.shape


novos_produtos = [ f'Produto {i}' for i in range(nrows)]

# A Quantidade de elementos da lista deve ser igual ao número de linhas do dataframe
data['PRODUTO'] = novos_produtos

data['PRODUTO']= produto_copy_bkp

# Criando uma coluna a partir de um valor constante/default
data['Coluna sem Nocao'] = 'DEFAULT'

# Criando uma coluina a partir de uma lista
data['Coluna a Partir de Lista'] =  range(data.shape[0])

# # Não funciona, devido a quantidade linhas do dataframe
# data['Não Funcionana'] = [1,2,3]

data['PREÇO MÉDIO REVENDA (dólares)'] = data['PREÇO MÉDIO REVENDA'] * 6.0

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO Coluna sem Nocao  \
# 0                              0.133   5  2004          DEFAULT
# 1                              0.115   5  2004          DEFAULT
# 2                              0.098   5  2004          DEFAULT
# 3                              0.143   5  2004          DEFAULT
# 4                              0.082   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          DEFAULT
# 106819                         0.164   6  2019          DEFAULT
# 106820                             0   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
# 106822                             0   6  2019          DEFAULT
#
#        Coluna a Partir de Lista  PREÇO MÉDIO REVENDA (dólares)
# 0                             0                          7.728
# 1                             1                          6.972
# 2                             2                          8.334
# 3                             3                          7.572
# 4                             4                          7.086
# ...                         ...                            ...
# 106818                   106818                         21.444
# 106819                   106819                         20.406
# 106820                   106820                         17.472
# 106821                   106821                         18.120
# 106822                   106822                         22.182
#
# [106823 rows x 24 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %%
pesquisa_de_satisfacao=pd.DataFrame({
    'Bom':[50,21,100],
    'Ruim':[21,2,20],
    'Pessimo':[100,30,1]
},index=['XboxOne','Playstation 4','Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#                Bom  Ruim  Pessimo
# XboxOne         50    21      100
# Playstation 4   21     2       30
# Switch         100    20        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation 4', 'Switch'], dtype='object')

# %%
# Index-Based Selection

data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   Coluna sem Nocao Coluna a Partir de Lista  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                          7.728
# 1          DEFAULT                        1                          6.972
# 2          DEFAULT                        2                          8.334
# 3          DEFAULT                        3                          7.572
# 4          DEFAULT                        4                          7.086
#
# [5 rows x 24 columns]

# %%
# seleciona a linha 1
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Coluna sem Nocao                          DEFAULT
# Coluna a Partir de Lista                        1
# PREÇO MÉDIO REVENDA (dólares)               6.972
# Name: 1, dtype: object

# %%
# Selecionar multiplas linhas - 1,2,3,4,5

data.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
# 5                1.383                  0.132  ...                     0.957
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
# 5                       0.128                    0.5686
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
# 5                       1.35                         0.134   5  2004
#
#   Coluna sem Nocao Coluna a Partir de Lista  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                          7.728
# 1          DEFAULT                        1                          6.972
# 2          DEFAULT                        2                          8.334
# 3          DEFAULT                        3                          7.572
# 4          DEFAULT                        4                          7.086
# 5          DEFAULT                        5                          8.298
#
# [6 rows x 24 columns]

# %%
data.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 10                1.573                  0.134  ...                     1.079
# 11                1.276                  0.116  ...                     0.944
# 12                1.301                  0.109  ...                      0.98
# 13                1.805                  0.134  ...                     1.116
# 14                1.785                  0.035  ...                     1.373
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 10                       0.078                    0.8857
# 11                       0.078                    0.7119
# 12                       0.052                    0.8267
# 13                       0.171                     0.767
# 14                       0.167                    0.8339
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 10                     1.2499                         0.072   5  2004
# 11                     1.1386                         0.083   5  2004
# 12                     1.1059                         0.053   5  2004
# 13                     1.2992                         0.153   5  2004
# 14                     1.4912                         0.122   5  2004
# 15                     1.2109                          0.06   5  2004
#
#    Coluna sem Nocao Coluna a Partir de Lista  PREÇO MÉDIO REVENDA (dólares)
# 10          DEFAULT                       10                          9.438
# 11          DEFAULT                       11                          7.656
# 12          DEFAULT                       12                          7.806
# 13          DEFAULT                       13                         10.830
# 14          DEFAULT                       14                         10.710
# 15          DEFAULT                       15                          9.468
#
# [6 rows x 24 columns]

# %%
data.iloc[[1,5,10,15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# 10                1.573                  0.134  ...                     1.079
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                        0.088                    0.5013
# 5                        0.128                    0.5686
# 10                       0.078                    0.8857
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 1                        1.05                         0.115   5  2004
# 5                        1.35                         0.134   5  2004
# 10                     1.2499                         0.072   5  2004
# 15                     1.2109                          0.06   5  2004
#
#    Coluna sem Nocao Coluna a Partir de Lista  PREÇO MÉDIO REVENDA (dólares)
# 1           DEFAULT                        1                          6.972
# 5           DEFAULT                        5                          8.298
# 10          DEFAULT                       10                          9.438
# 15          DEFAULT                       15                          9.468
#
# [4 rows x 24 columns]

# %%
data.iloc[[5,1,15,10]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                 1.383                  0.132  ...                     0.957
# 1                 1.162                  0.114  ...                     0.763
# 15                1.578                  0.123  ...                     1.137
# 10                1.573                  0.134  ...                     1.079
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5                        0.128                    0.5686
# 1                        0.088                    0.5013
# 15                       0.068                    0.9515
# 10                       0.078                    0.8857
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 5                        1.35                         0.134   5  2004
# 1                        1.05                         0.115   5  2004
# 15                     1.2109                          0.06   5  2004
# 10                     1.2499                         0.072   5  2004
#
#    Coluna sem Nocao Coluna a Partir de Lista  PREÇO MÉDIO REVENDA (dólares)
# 5           DEFAULT                        5                          8.298
# 1           DEFAULT                        1                          6.972
# 15          DEFAULT                       15                          9.468
# 10          DEFAULT                       10                          9.438
#
# [4 rows x 24 columns]

# %%
data.iloc[1,3]
# Out:
# 'GOIAS'

# %%
pesquisa_de_satisfacao
# Out:
#                Bom  Ruim  Pessimo
# XboxOne         50    21      100
# Playstation 4   21     2       30
# Switch         100    20        1

# %%
# Retorna a linha de Indice 0 Implcito   
pesquisa_de_satisfacao.iloc[0]
# Out:
# Bom         50
# Ruim        21
# Pessimo    100
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao.iloc[0,1]
# Out:
# np.int64(21)

# %%
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# Bom         50
# Ruim        21
# Pessimo    100
# Name: XboxOne, dtype: int64

# %%
# Não funciona
pesquisa_de_satisfacao.iloc['XboxOne']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Não funciona
# ----> 2 pesquisa_de_satisfacao.iloc['XboxOne']
#
# File d:\GitHub\EstudoPandas\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\GitHub\EstudoPandas\.venv\Lib\site-packages\pandas\core\indexing.py:1749, in _iLocIndexer._getitem_axis(self, key, axis)
#    1747 key = item_from_zerodim(key)
#    1748 if not is_integer(key):
# -> 1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
#    1752 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
# Não Funciona
pesquisa_de_satisfacao.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\GitHub\EstudoPandas\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Não Funciona
# ----> 2 pesquisa_de_satisfacao.loc[0]
#
# File d:\GitHub\EstudoPandas\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\GitHub\EstudoPandas\.venv\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File d:\GitHub\EstudoPandas\.venv\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File d:\GitHub\EstudoPandas\.venv\Lib\site-packages\pandas\core\generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File d:\GitHub\EstudoPandas\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 0

# %%
pesquisa_de_satisfacao
# Out:
#                Bom  Ruim  Pessimo
# XboxOne         50    21      100
# Playstation 4   21     2       30
# Switch         100    20        1

# %%
pesquisa_de_satisfacao.loc['Playstation 4','Ruim']
# Out:
# np.int64(2)

# %%
pesquisa_de_satisfacao.loc[['XboxOne','Switch']]
# Out:
#          Bom  Ruim  Pessimo
# XboxOne   50    21      100
# Switch   100    20        1
